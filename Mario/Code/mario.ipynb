# %%
# !pip install gym-super-mario-bros

# %%
import gym_super_mario_bros
from nes_py.wrappers import JoypadSpace
from gym_super_mario_bros.actions import SIMPLE_MOVEMENT
from gym.wrappers import FrameStack, GrayScaleObservation
from stable_baselines3.common.vec_env import VecFrameStack, DummyVecEnv
from stable_baselines3.common.env_checker import check_env
from stable_baselines3.common.callbacks import BaseCallback
import os
import sys
import time
import numpy as np
import random
import math
from stable_baselines3 import PPO, DQN
import matplotlib.pyplot as plt

# %%
SIMPLE_MOVEMENT
# Out:
# [['NOOP'],
#  ['right'],
#  ['right', 'A'],
#  ['right', 'B'],
#  ['right', 'A', 'B'],
#  ['A'],
#  ['left']]

# %%
env = gym_super_mario_bros.make('SuperMarioBros2-v1')
env = JoypadSpace(env, SIMPLE_MOVEMENT)
env = GrayScaleObservation(env, keep_dim=True)
env = DummyVecEnv([lambda: env])
env = VecFrameStack(env, 4, channels_order='last')

# %%
env.action_space
# Out:
# Discrete(7)

# %%
env.observation_space.shape
# Out:
# (240, 256, 4)

# %%
stepsize = 10000

# %% [markdown]
# Test Env

# %%
# env.reset()
# done = True
# stepsize = 10000
# for _ in range(stepsize):
#     if done:
#         env.reset()
#         # break
#     state, reward, done, info = env.step(env.action_space.sample())
#     env.render()
# env.close()

# %%
# From https://github.com/nicknochnack/MarioRL/blob/main/Mario%20Tutorial.ipynb
class TrainAndLoggingCallback(BaseCallback):

    def __init__(self, check_freq, save_path, verbose=1):
        super(TrainAndLoggingCallback, self).__init__(verbose)
        self.check_freq = check_freq
        self.save_path = save_path

    def _init_callback(self):
        if self.save_path is not None:
            os.makedirs(self.save_path, exist_ok=True)

    def _on_step(self):
        if self.n_calls % self.check_freq == 0:
            model_path = os.path.join(self.save_path, 'best_model_{}'.format(self.n_calls))
            self.model.save(model_path)

        return True

# %%
CHECKPOINT_DIR = './train/'
LOG_DIR = './logs/'


if not os.path.exists(CHECKPOINT_DIR):
    os.makedirs(CHECKPOINT_DIR)

if not os.path.exists(LOG_DIR):
    os.makedirs(LOG_DIR)

# Setup model saving callback
callback = TrainAndLoggingCallback(check_freq=1000, save_path=CHECKPOINT_DIR)

# %%
# This is the AI model started
model = PPO('CnnPolicy', env, verbose=1, tensorboard_log=LOG_DIR, learning_rate=0.001, 
            n_steps=512)
# Out:
# Using cpu device
# Wrapping the env in a VecTransposeImage.

# %%
model.learn(total_timesteps=100000, callback=callback, reset_num_timesteps=False, tb_log_name='PPO-3')
# Out:
# Logging to ./logs/PPO-3_0
# ----------------------------
# | time/              |     |
# |    fps             | 52  |
# |    iterations      | 1   |
# |    time_elapsed    | 9   |
# |    total_timesteps | 512 |
# ----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 10          |
# |    iterations           | 2           |
# |    time_elapsed         | 98          |
# |    total_timesteps      | 1024        |
# | train/                  |             |
# |    approx_kl            | 0.085928135 |
# |    clip_fraction        | 0.513       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.88       |
# |    explained_variance   | -0.000406   |
# |    learning_rate        | 0.001       |
# |    loss                 | 5.79        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | 0.0368      |
# |    value_loss           | 43.7        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 8          |
# |    iterations           | 3          |
# |    time_elapsed         | 177        |
# |    total_timesteps      | 1536       |
# | train/                  |            |
# |    approx_kl            | 0.28382808 |
# |    clip_fraction        | 0.702      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.74      |
# |    explained_variance   | -0.685     |
# |    learning_rate        | 0.001      |
# |    loss                 | 0.464      |
# |    n_updates            | 20         |
# |    policy_gradient_loss | 0.0905     |
# |    value_loss           | 4.82       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 7          |
# |    iterations           | 4          |
# |    time_elapsed         | 260        |
# |    total_timesteps      | 2048       |
# | train/                  |            |
# |    approx_kl            | 0.14251997 |
# |    clip_fraction        | 0.6        |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.52      |
# |    explained_variance   | -0.155     |
# |    learning_rate        | 0.001      |
# |    loss                 | 0.428      |
# |    n_updates            | 30         |
# |    policy_gradient_loss | 0.0594     |
# |    value_loss           | 5.97       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 7          |
# |    iterations           | 5          |
# |    time_elapsed         | 338        |
# |    total_timesteps      | 2560       |
# | train/                  |            |
# |    approx_kl            | 0.02035058 |
# |    clip_fraction        | 0.389      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.55      |
# |    explained_variance   | 0.283      |
# |    learning_rate        | 0.001      |
# |    loss                 | 0.0858     |
# |    n_updates            | 40         |
# |    policy_gradient_loss | 0.019      |
# |    value_loss           | 0.569      |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 7           |
# |    iterations           | 6           |
# |    time_elapsed         | 420         |
# |    total_timesteps      | 3072        |
# | train/                  |             |
# |    approx_kl            | 0.014197541 |
# |    clip_fraction        | 0.304       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.63       |
# |    explained_variance   | -0.0998     |
# |    learning_rate        | 0.001       |
# |    loss                 | 0.0381      |
# |    n_updates            | 50          |
# |    policy_gradient_loss | 0.00938     |
# |    value_loss           | 0.437       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 7           |
# |    iterations           | 7           |
# |    time_elapsed         | 489         |
# |    total_timesteps      | 3584        |
# | train/                  |             |
# |    approx_kl            | 0.011861179 |
# |    clip_fraction        | 0.247       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.68       |
# |    explained_variance   | -0.346      |
# |    learning_rate        | 0.001       |
# |    loss                 | 0.055       |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0134     |
# |    value_loss           | 0.3         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 7           |
# |    iterations           | 8           |
# |    time_elapsed         | 568         |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.016590768 |
# |    clip_fraction        | 0.179       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.7        |
# |    explained_variance   | 0.401       |
# |    learning_rate        | 0.001       |
# |    loss                 | -0.0104     |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00867    |
# |    value_loss           | 0.234       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 7           |
# |    iterations           | 9           |
# |    time_elapsed         | 643         |
# |    total_timesteps      | 4608        |
# | train/                  |             |
# |    approx_kl            | 0.006887125 |
# |    clip_fraction        | 0.0467      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.7        |
# |    explained_variance   | 0.376       |
# |    learning_rate        | 0.001       |
# |    loss                 | -0.00108    |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00386    |
# |    value_loss           | 0.137       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 6            |
# |    iterations           | 10           |
# |    time_elapsed         | 738          |
# |    total_timesteps      | 5120         |
# | train/                  |              |
# |    approx_kl            | 0.0063597374 |
# |    clip_fraction        | 0.114        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.7         |
# |    explained_variance   | 0.46         |
# |    learning_rate        | 0.001        |
# |    loss                 | -0.0287      |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.0148      |
# |    value_loss           | 0.0895       |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 6           |
# |    iterations           | 11          |
# |    time_elapsed         | 845         |
# |    total_timesteps      | 5632        |
# | train/                  |             |
# |    approx_kl            | 0.021930628 |
# |    clip_fraction        | 0.25        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.74       |
# |    explained_variance   | 0.416       |
# |    learning_rate        | 0.001       |
# |    loss                 | -0.0366     |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0236     |
# |    value_loss           | 0.0765      |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 6          |
# |    iterations           | 12         |
# |    time_elapsed         | 968        |
# |    total_timesteps      | 6144       |
# | train/                  |            |
# |    approx_kl            | 0.04045201 |
# |    clip_fraction        | 0.311      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.78      |
# |    explained_variance   | 0.178      |
# |    learning_rate        | 0.001      |
# |    loss                 | -0.0664    |
# |    n_updates            | 110        |
# |    policy_gradient_loss | -0.0405    |
# |    value_loss           | 0.0991     |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 6          |
# |    iterations           | 13         |
# |    time_elapsed         | 1064       |
# |    total_timesteps      | 6656       |
# | train/                  |            |
# |    approx_kl            | 0.07724118 |
# |    clip_fraction        | 0.437      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.76      |
# |    explained_variance   | 0.329      |
# |    learning_rate        | 0.001      |
# |    loss                 | -0.102     |
# |    n_updates            | 120        |
# |    policy_gradient_loss | -0.0733    |
# |    value_loss           | 0.0503     |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 6          |
# |    iterations           | 14         |
# |    time_elapsed         | 1173       |
# |    total_timesteps      | 7168       |
# | train/                  |            |
# |    approx_kl            | 0.10707681 |
# |    clip_fraction        | 0.521      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.69      |
# |    explained_variance   | 0.486      |
# |    learning_rate        | 0.001      |
# |    loss                 | -0.114     |
# |    n_updates            | 130        |
# |    policy_gradient_loss | -0.0943    |
# |    value_loss           | 0.0398     |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 6          |
# |    iterations           | 15         |
# |    time_elapsed         | 1270       |
# |    total_timesteps      | 7680       |
# | train/                  |            |
# |    approx_kl            | 0.12472284 |
# |    clip_fraction        | 0.555      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.61      |
# |    explained_variance   | 0.545      |
# |    learning_rate        | 0.001      |
# |    loss                 | -0.134     |
# |    n_updates            | 140        |
# |    policy_gradient_loss | -0.0952    |
# |    value_loss           | 0.036      |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 5          |
# |    iterations           | 16         |
# |    time_elapsed         | 1373       |
# |    total_timesteps      | 8192       |
# | train/                  |            |
# |    approx_kl            | 0.10873537 |
# |    clip_fraction        | 0.584      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.68      |
# |    explained_variance   | 0.522      |
# |    learning_rate        | 0.001      |
# |    loss                 | -0.131     |
# |    n_updates            | 150        |
# |    policy_gradient_loss | -0.0948    |
# |    value_loss           | 0.0352     |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 5           |
# |    iterations           | 17          |
# |    time_elapsed         | 1470        |
# |    total_timesteps      | 8704        |
# | train/                  |             |
# |    approx_kl            | 0.093245625 |
# |    clip_fraction        | 0.526       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.62       |
# |    explained_variance   | 0.581       |
# |    learning_rate        | 0.001       |
# |    loss                 | -0.118      |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0834     |
# |    value_loss           | 0.0297      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 5           |
# |    iterations           | 18          |
# |    time_elapsed         | 1575        |
# |    total_timesteps      | 9216        |
# | train/                  |             |
# |    approx_kl            | 0.070849515 |
# |    clip_fraction        | 0.498       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.65       |
# |    explained_variance   | 0.39        |
# |    learning_rate        | 0.001       |
# |    loss                 | -0.0918     |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0682     |
# |    value_loss           | 0.102       |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 5          |
# |    iterations           | 19         |
# |    time_elapsed         | 1671       |
# |    total_timesteps      | 9728       |
# | train/                  |            |
# |    approx_kl            | 0.13043138 |
# |    clip_fraction        | 0.594      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.62      |
# |    explained_variance   | 0.176      |
# |    learning_rate        | 0.001      |
# |    loss                 | -0.0819    |
# |    n_updates            | 180        |
# |    policy_gradient_loss | -0.0969    |
# |    value_loss           | 0.126      |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 5          |
# |    iterations           | 20         |
# |    time_elapsed         | 1781       |
# |    total_timesteps      | 10240      |
# | train/                  |            |
# |    approx_kl            | 0.15119374 |
# |    clip_fraction        | 0.621      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.63      |
# |    explained_variance   | 0.0245     |
# |    learning_rate        | 0.001      |
# |    loss                 | -0.0918    |
# |    n_updates            | 190        |
# |    policy_gradient_loss | -0.0994    |
# |    value_loss           | 0.124      |
# ----------------------------------------
# --------------------------------------
# | time/                   |          |
# |    fps                  | 5        |
# |    iterations           | 21       |
# |    time_elapsed         | 1869     |
# |    total_timesteps      | 10752    |
# | train/                  |          |
# |    approx_kl            | 4.508073 |
# |    clip_fraction        | 0.801    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -1.03    |
# |    explained_variance   | 0.0455   |
# |    learning_rate        | 0.001    |
# |    loss                 | 0.897    |
# |    n_updates            | 200      |
# |    policy_gradient_loss | 0.187    |
# |    value_loss           | 72       |
# --------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 5          |
# |    iterations           | 22         |
# |    time_elapsed         | 1966       |
# |    total_timesteps      | 11264      |
# | train/                  |            |
# |    approx_kl            | 0.11502283 |
# |    clip_fraction        | 0.591      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.5       |
# |    explained_variance   | 0.522      |
# |    learning_rate        | 0.001      |
# |    loss                 | -0.0672    |
# |    n_updates            | 210        |
# |    policy_gradient_loss | -0.0549    |
# |    value_loss           | 0.5        |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 5          |
# |    iterations           | 23         |
# |    time_elapsed         | 2054       |
# |    total_timesteps      | 11776      |
# | train/                  |            |
# |    approx_kl            | 0.11402041 |
# |    clip_fraction        | 0.541      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.54      |
# |    explained_variance   | 0.219      |
# |    learning_rate        | 0.001      |
# |    loss                 | -0.0678    |
# |    n_updates            | 220        |
# |    policy_gradient_loss | -0.0863    |
# |    value_loss           | 0.15       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 5          |
# |    iterations           | 24         |
# |    time_elapsed         | 2153       |
# |    total_timesteps      | 12288      |
# | train/                  |            |
# |    approx_kl            | 0.10611254 |
# |    clip_fraction        | 0.54       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.52      |
# |    explained_variance   | 0.221      |
# |    learning_rate        | 0.001      |
# |    loss                 | -0.084     |
# |    n_updates            | 230        |
# |    policy_gradient_loss | -0.0908    |
# |    value_loss           | 0.125      |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 5          |
# |    iterations           | 25         |
# |    time_elapsed         | 2261       |
# |    total_timesteps      | 12800      |
# | train/                  |            |
# |    approx_kl            | 0.11520489 |
# |    clip_fraction        | 0.567      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.58      |
# |    explained_variance   | 0.219      |
# |    learning_rate        | 0.001      |
# |    loss                 | -0.0608    |
# |    n_updates            | 240        |
# |    policy_gradient_loss | -0.0881    |
# |    value_loss           | 0.148      |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 5          |
# |    iterations           | 26         |
# |    time_elapsed         | 2377       |
# |    total_timesteps      | 13312      |
# | train/                  |            |
# |    approx_kl            | 0.17058694 |
# |    clip_fraction        | 0.596      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.42      |
# |    explained_variance   | 0.215      |
# |    learning_rate        | 0.001      |
# |    loss                 | -0.0962    |
# |    n_updates            | 250        |
# |    policy_gradient_loss | -0.0975    |
# |    value_loss           | 0.112      |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 5          |
# |    iterations           | 27         |
# |    time_elapsed         | 2487       |
# |    total_timesteps      | 13824      |
# | train/                  |            |
# |    approx_kl            | 0.15187342 |
# |    clip_fraction        | 0.574      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.32      |
# |    explained_variance   | 0.0467     |
# |    learning_rate        | 0.001      |
# |    loss                 | -0.0808    |
# |    n_updates            | 260        |
# |    policy_gradient_loss | -0.0898    |
# |    value_loss           | 0.0926     |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 5          |
# |    iterations           | 28         |
# |    time_elapsed         | 2598       |
# |    total_timesteps      | 14336      |
# | train/                  |            |
# |    approx_kl            | 0.16047044 |
# |    clip_fraction        | 0.625      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.3       |
# |    explained_variance   | 0.257      |
# |    learning_rate        | 0.001      |
# |    loss                 | -0.131     |
# |    n_updates            | 270        |
# |    policy_gradient_loss | -0.108     |
# |    value_loss           | 0.0334     |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 5          |
# |    iterations           | 29         |
# |    time_elapsed         | 2712       |
# |    total_timesteps      | 14848      |
# | train/                  |            |
# |    approx_kl            | 0.23354219 |
# |    clip_fraction        | 0.611      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.26      |
# |    explained_variance   | 0.524      |
# |    learning_rate        | 0.001      |
# |    loss                 | -0.111     |
# |    n_updates            | 280        |
# |    policy_gradient_loss | -0.102     |
# |    value_loss           | 0.0242     |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 5          |
# |    iterations           | 30         |
# |    time_elapsed         | 2837       |
# |    total_timesteps      | 15360      |
# | train/                  |            |
# |    approx_kl            | 0.25312662 |
# |    clip_fraction        | 0.647      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.14      |
# |    explained_variance   | 0.666      |
# |    learning_rate        | 0.001      |
# |    loss                 | -0.119     |
# |    n_updates            | 290        |
# |    policy_gradient_loss | -0.0955    |
# |    value_loss           | 0.0193     |
# ----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 5         |
# |    iterations           | 31        |
# |    time_elapsed         | 2950      |
# |    total_timesteps      | 15872     |
# | train/                  |           |
# |    approx_kl            | 0.2530961 |
# |    clip_fraction        | 0.607     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.1      |
# |    explained_variance   | 0.663     |
# |    learning_rate        | 0.001     |
# |    loss                 | -0.126    |
# |    n_updates            | 300       |
# |    policy_gradient_loss | -0.0926   |
# |    value_loss           | 0.0204    |
# ---------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 5          |
# |    iterations           | 32         |
# |    time_elapsed         | 3055       |
# |    total_timesteps      | 16384      |
# | train/                  |            |
# |    approx_kl            | 0.37501252 |
# |    clip_fraction        | 0.653      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.09      |
# |    explained_variance   | 0.504      |
# |    learning_rate        | 0.001      |
# |    loss                 | -0.101     |
# |    n_updates            | 310        |
# |    policy_gradient_loss | -0.0999    |
# |    value_loss           | 0.0245     |
# ----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 5         |
# |    iterations           | 33        |
# |    time_elapsed         | 3155      |
# |    total_timesteps      | 16896     |
# | train/                  |           |
# |    approx_kl            | 0.2593044 |
# |    clip_fraction        | 0.591     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.996    |
# |    explained_variance   | 0.66      |
# |    learning_rate        | 0.001     |
# |    loss                 | -0.107    |
# |    n_updates            | 320       |
# |    policy_gradient_loss | -0.0872   |
# |    value_loss           | 0.0198    |
# ---------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 5          |
# |    iterations           | 34         |
# |    time_elapsed         | 3262       |
# |    total_timesteps      | 17408      |
# | train/                  |            |
# |    approx_kl            | 0.28573307 |
# |    clip_fraction        | 0.65       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.12      |
# |    explained_variance   | 0.725      |
# |    learning_rate        | 0.001      |
# |    loss                 | -0.14      |
# |    n_updates            | 330        |
# |    policy_gradient_loss | -0.103     |
# |    value_loss           | 0.014      |
# ----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 5         |
# |    iterations           | 35        |
# |    time_elapsed         | 3358      |
# |    total_timesteps      | 17920     |
# | train/                  |           |
# |    approx_kl            | 0.2872863 |
# |    clip_fraction        | 0.643     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.21     |
# |    explained_variance   | 0.601     |
# |    learning_rate        | 0.001     |
# |    loss                 | -0.113    |
# |    n_updates            | 340       |
# |    policy_gradient_loss | -0.0927   |
# |    value_loss           | 0.0185    |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 5         |
# |    iterations           | 36        |
# |    time_elapsed         | 3466      |
# |    total_timesteps      | 18432     |
# | train/                  |           |
# |    approx_kl            | 0.2646373 |
# |    clip_fraction        | 0.613     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.16     |
# |    explained_variance   | 0.7       |
# |    learning_rate        | 0.001     |
# |    loss                 | -0.128    |
# |    n_updates            | 350       |
# |    policy_gradient_loss | -0.0959   |
# |    value_loss           | 0.0175    |
# ---------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 5          |
# |    iterations           | 37         |
# |    time_elapsed         | 3575       |
# |    total_timesteps      | 18944      |
# | train/                  |            |
# |    approx_kl            | 0.22038127 |
# |    clip_fraction        | 0.653      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.24      |
# |    explained_variance   | 0.541      |
# |    learning_rate        | 0.001      |
# |    loss                 | -0.141     |
# |    n_updates            | 360        |
# |    policy_gradient_loss | -0.107     |
# |    value_loss           | 0.0203     |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 5          |
# |    iterations           | 38         |
# |    time_elapsed         | 3674       |
# |    total_timesteps      | 19456      |
# | train/                  |            |
# |    approx_kl            | 0.22989358 |
# |    clip_fraction        | 0.643      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.34      |
# |    explained_variance   | 0.497      |
# |    learning_rate        | 0.001      |
# |    loss                 | -0.109     |
# |    n_updates            | 370        |
# |    policy_gradient_loss | -0.103     |
# |    value_loss           | 0.0259     |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 5          |
# |    iterations           | 39         |
# |    time_elapsed         | 3765       |
# |    total_timesteps      | 19968      |
# | train/                  |            |
# |    approx_kl            | 0.33813393 |
# |    clip_fraction        | 0.605      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.11      |
# |    explained_variance   | 0.361      |
# |    learning_rate        | 0.001      |
# |    loss                 | 0.13       |
# |    n_updates            | 380        |
# |    policy_gradient_loss | 0.0756     |
# |    value_loss           | 6.96       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 5          |
# |    iterations           | 40         |
# |    time_elapsed         | 3859       |
# |    total_timesteps      | 20480      |
# | train/                  |            |
# |    approx_kl            | 0.39691448 |
# |    clip_fraction        | 0.473      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.559     |
# |    explained_variance   | 0.589      |
# |    learning_rate        | 0.001      |
# |    loss                 | 0.226      |
# |    n_updates            | 390        |
# |    policy_gradient_loss | 0.0355     |
# |    value_loss           | 36.4       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 5          |
# |    iterations           | 41         |
# |    time_elapsed         | 3946       |
# |    total_timesteps      | 20992      |
# | train/                  |            |
# |    approx_kl            | 0.29379624 |
# |    clip_fraction        | 0.518      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.824     |
# |    explained_variance   | 0.246      |
# |    learning_rate        | 0.001      |
# |    loss                 | -0.0493    |
# |    n_updates            | 400        |
# |    policy_gradient_loss | -0.034     |
# |    value_loss           | 0.305      |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 5          |
# |    iterations           | 42         |
# |    time_elapsed         | 4039       |
# |    total_timesteps      | 21504      |
# | train/                  |            |
# |    approx_kl            | 0.24896161 |
# |    clip_fraction        | 0.5        |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.899     |
# |    explained_variance   | -0.0774    |
# |    learning_rate        | 0.001      |
# |    loss                 | -0.0791    |
# |    n_updates            | 410        |
# |    policy_gradient_loss | -0.072     |
# |    value_loss           | 0.0686     |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 5          |
# |    iterations           | 43         |
# |    time_elapsed         | 4133       |
# |    total_timesteps      | 22016      |
# | train/                  |            |
# |    approx_kl            | 0.21010903 |
# |    clip_fraction        | 0.553      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.926     |
# |    explained_variance   | 0.00723    |
# |    learning_rate        | 0.001      |
# |    loss                 | -0.0801    |
# |    n_updates            | 420        |
# |    policy_gradient_loss | -0.0942    |
# |    value_loss           | 0.0608     |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 5          |
# |    iterations           | 44         |
# |    time_elapsed         | 4218       |
# |    total_timesteps      | 22528      |
# | train/                  |            |
# |    approx_kl            | 0.31536615 |
# |    clip_fraction        | 0.591      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1         |
# |    explained_variance   | 0.194      |
# |    learning_rate        | 0.001      |
# |    loss                 | -0.134     |
# |    n_updates            | 430        |
# |    policy_gradient_loss | -0.0866    |
# |    value_loss           | 0.0408     |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 5          |
# |    iterations           | 45         |
# |    time_elapsed         | 4312       |
# |    total_timesteps      | 23040      |
# | train/                  |            |
# |    approx_kl            | 0.30645287 |
# |    clip_fraction        | 0.588      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1         |
# |    explained_variance   | -0.336     |
# |    learning_rate        | 0.001      |
# |    loss                 | -0.108     |
# |    n_updates            | 440        |
# |    policy_gradient_loss | -0.0882    |
# |    value_loss           | 0.0576     |
# ----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 5         |
# |    iterations           | 46        |
# |    time_elapsed         | 4399      |
# |    total_timesteps      | 23552     |
# | train/                  |           |
# |    approx_kl            | 0.3138942 |
# |    clip_fraction        | 0.567     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.941    |
# |    explained_variance   | -0.258    |
# |    learning_rate        | 0.001     |
# |    loss                 | -0.129    |
# |    n_updates            | 450       |
# |    policy_gradient_loss | -0.0885   |
# |    value_loss           | 0.0524    |
# ---------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 5          |
# |    iterations           | 47         |
# |    time_elapsed         | 4495       |
# |    total_timesteps      | 24064      |
# | train/                  |            |
# |    approx_kl            | 0.27847368 |
# |    clip_fraction        | 0.563      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1         |
# |    explained_variance   | -0.0402    |
# |    learning_rate        | 0.001      |
# |    loss                 | -0.114     |
# |    n_updates            | 460        |
# |    policy_gradient_loss | -0.0794    |
# |    value_loss           | 0.0462     |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 5          |
# |    iterations           | 48         |
# |    time_elapsed         | 4584       |
# |    total_timesteps      | 24576      |
# | train/                  |            |
# |    approx_kl            | 0.26101622 |
# |    clip_fraction        | 0.57       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.975     |
# |    explained_variance   | -0.216     |
# |    learning_rate        | 0.001      |
# |    loss                 | -0.112     |
# |    n_updates            | 470        |
# |    policy_gradient_loss | -0.0889    |
# |    value_loss           | 0.0531     |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 5          |
# |    iterations           | 49         |
# |    time_elapsed         | 4689       |
# |    total_timesteps      | 25088      |
# | train/                  |            |
# |    approx_kl            | 0.30296695 |
# |    clip_fraction        | 0.619      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.02      |
# |    explained_variance   | -0.00762   |
# |    learning_rate        | 0.001      |
# |    loss                 | -0.116     |
# |    n_updates            | 480        |
# |    policy_gradient_loss | -0.0984    |
# |    value_loss           | 0.0468     |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 5          |
# |    iterations           | 50         |
# |    time_elapsed         | 4780       |
# |    total_timesteps      | 25600      |
# | train/                  |            |
# |    approx_kl            | 0.24988836 |
# |    clip_fraction        | 0.617      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.07      |
# |    explained_variance   | -0.151     |
# |    learning_rate        | 0.001      |
# |    loss                 | -0.109     |
# |    n_updates            | 490        |
# |    policy_gradient_loss | -0.0911    |
# |    value_loss           | 0.0483     |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 5          |
# |    iterations           | 51         |
# |    time_elapsed         | 4883       |
# |    total_timesteps      | 26112      |
# | train/                  |            |
# |    approx_kl            | 0.40251747 |
# |    clip_fraction        | 0.561      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.974     |
# |    explained_variance   | 0.0709     |
# |    learning_rate        | 0.001      |
# |    loss                 | -0.11      |
# |    n_updates            | 500        |
# |    policy_gradient_loss | -0.0887    |
# |    value_loss           | 0.0493     |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 5          |
# |    iterations           | 52         |
# |    time_elapsed         | 4975       |
# |    total_timesteps      | 26624      |
# | train/                  |            |
# |    approx_kl            | 0.28991944 |
# |    clip_fraction        | 0.607      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.993     |
# |    explained_variance   | -0.0374    |
# |    learning_rate        | 0.001      |
# |    loss                 | -0.138     |
# |    n_updates            | 510        |
# |    policy_gradient_loss | -0.099     |
# |    value_loss           | 0.0368     |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 5          |
# |    iterations           | 53         |
# |    time_elapsed         | 5077       |
# |    total_timesteps      | 27136      |
# | train/                  |            |
# |    approx_kl            | 0.34369808 |
# |    clip_fraction        | 0.605      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.986     |
# |    explained_variance   | -0.303     |
# |    learning_rate        | 0.001      |
# |    loss                 | -0.122     |
# |    n_updates            | 520        |
# |    policy_gradient_loss | -0.104     |
# |    value_loss           | 0.0421     |
# ----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 5         |
# |    iterations           | 54        |
# |    time_elapsed         | 5172      |
# |    total_timesteps      | 27648     |
# | train/                  |           |
# |    approx_kl            | 0.3440511 |
# |    clip_fraction        | 0.643     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.11     |
# |    explained_variance   | 0.121     |
# |    learning_rate        | 0.001     |
# |    loss                 | -0.111    |
# |    n_updates            | 530       |
# |    policy_gradient_loss | -0.102    |
# |    value_loss           | 0.0443    |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 5         |
# |    iterations           | 55        |
# |    time_elapsed         | 5276      |
# |    total_timesteps      | 28160     |
# | train/                  |           |
# |    approx_kl            | 0.2822276 |
# |    clip_fraction        | 0.592     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.11     |
# |    explained_variance   | 0.196     |
# |    learning_rate        | 0.001     |
# |    loss                 | -0.107    |
# |    n_updates            | 540       |
# |    policy_gradient_loss | -0.0935   |
# |    value_loss           | 0.0442    |
# ---------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 5          |
# |    iterations           | 56         |
# |    time_elapsed         | 5375       |
# |    total_timesteps      | 28672      |
# | train/                  |            |
# |    approx_kl            | 0.49381235 |
# |    clip_fraction        | 0.645      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.09      |
# |    explained_variance   | -0.072     |
# |    learning_rate        | 0.001      |
# |    loss                 | -0.0741    |
# |    n_updates            | 550        |
# |    policy_gradient_loss | -0.0968    |
# |    value_loss           | 0.102      |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 5          |
# |    iterations           | 57         |
# |    time_elapsed         | 5480       |
# |    total_timesteps      | 29184      |
# | train/                  |            |
# |    approx_kl            | 0.29185888 |
# |    clip_fraction        | 0.596      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.02      |
# |    explained_variance   | -0.311     |
# |    learning_rate        | 0.001      |
# |    loss                 | -0.0686    |
# |    n_updates            | 560        |
# |    policy_gradient_loss | -0.102     |
# |    value_loss           | 0.135      |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 5          |
# |    iterations           | 58         |
# |    time_elapsed         | 5576       |
# |    total_timesteps      | 29696      |
# | train/                  |            |
# |    approx_kl            | 0.31760895 |
# |    clip_fraction        | 0.429      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.693     |
# |    explained_variance   | 0.594      |
# |    learning_rate        | 0.001      |
# |    loss                 | 0.226      |
# |    n_updates            | 570        |
# |    policy_gradient_loss | 0.0105     |
# |    value_loss           | 16.6       |
# ----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 5         |
# |    iterations           | 59        |
# |    time_elapsed         | 5676      |
# |    total_timesteps      | 30208     |
# | train/                  |           |
# |    approx_kl            | 0.4099412 |
# |    clip_fraction        | 0.376     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.597    |
# |    explained_variance   | 0.801     |
# |    learning_rate        | 0.001     |
# |    loss                 | 0.757     |
# |    n_updates            | 580       |
# |    policy_gradient_loss | -0.000296 |
# |    value_loss           | 14.6      |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 5         |
# |    iterations           | 60        |
# |    time_elapsed         | 5769      |
# |    total_timesteps      | 30720     |
# | train/                  |           |
# |    approx_kl            | 0.3781695 |
# |    clip_fraction        | 0.532     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.88     |
# |    explained_variance   | -0.086    |
# |    learning_rate        | 0.001     |
# |    loss                 | -0.059    |
# |    n_updates            | 590       |
# |    policy_gradient_loss | -0.0735   |
# |    value_loss           | 0.166     |
# ---------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 5          |
# |    iterations           | 61         |
# |    time_elapsed         | 5871       |
# |    total_timesteps      | 31232      |
# | train/                  |            |
# |    approx_kl            | 0.48934337 |
# |    clip_fraction        | 0.578      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.849     |
# |    explained_variance   | 0.11       |
# |    learning_rate        | 0.001      |
# |    loss                 | -0.106     |
# |    n_updates            | 600        |
# |    policy_gradient_loss | -0.0831    |
# |    value_loss           | 0.0911     |
# ----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 5         |
# |    iterations           | 62        |
# |    time_elapsed         | 5961      |
# |    total_timesteps      | 31744     |
# | train/                  |           |
# |    approx_kl            | 0.3512562 |
# |    clip_fraction        | 0.583     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.79     |
# |    explained_variance   | -0.0432   |
# |    learning_rate        | 0.001     |
# |    loss                 | -0.112    |
# |    n_updates            | 610       |
# |    policy_gradient_loss | -0.0928   |
# |    value_loss           | 0.0936    |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 5         |
# |    iterations           | 63        |
# |    time_elapsed         | 6061      |
# |    total_timesteps      | 32256     |
# | train/                  |           |
# |    approx_kl            | 0.3144061 |
# |    clip_fraction        | 0.56      |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.808    |
# |    explained_variance   | 0.0839    |
# |    learning_rate        | 0.001     |
# |    loss                 | -0.113    |
# |    n_updates            | 620       |
# |    policy_gradient_loss | -0.0879   |
# |    value_loss           | 0.0809    |
# ---------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20556\2637393526.py in <module>
# ----> 1 model.learn(total_timesteps=100000, callback=callback, reset_num_timesteps=False, tb_log_name='PPO-3')
#
# d:\Anaconda\lib\site-packages\stable_baselines3\ppo\ppo.py in learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     305     ) -> SelfPPO:
#     306
# --> 307         return super().learn(
#     308             total_timesteps=total_timesteps,
#     309             callback=callback,
#
# d:\Anaconda\lib\site-packages\stable_baselines3\common\on_policy_algorithm.py in learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     267                 self.logger.dump(step=self.num_timesteps)
#     268
# --> 269             self.train()
#     270
#     271         callback.on_training_end()
#
# d:\Anaconda\lib\site-packages\stable_baselines3\ppo\ppo.py in train(self)
#     268                 # Optimization step
#     269                 self.policy.optimizer.zero_grad()
# --> 270                 loss.backward()
#     271                 # Clip grad norm
#     272                 th.nn.utils.clip_grad_norm_(self.policy.parameters(), self.max_grad_norm)
#
# d:\Anaconda\lib\site-packages\torch\_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     485                 inputs=inputs,
#     486             )
# --> 487         torch.autograd.backward(
#     488             self, gradient, retain_graph, create_graph, inputs=inputs
#     489         )
#
# d:\Anaconda\lib\site-packages\torch\autograd\__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     198     # some Python versions print out the first line of a multi-line function
#     199     # calls in the traceback and some print out the last line
# --> 200     Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     201         tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     202         allow_unreachable=True, accumulate_grad=True)  # Calls into the C++ engine to run the backward pass
#
# KeyboardInterrupt:

# %%
model.save('thisisatestmodel')

# %% [markdown]
# For Results

# %%
model = PPO.load('./train/best_model_18000')

# %%
# Start the game 
state = env.reset()
# Loop through the game
while True: 
    
    action, _ = model.predict(state)
    state, reward, done, info = env.step(action)
    env.render()
# Out:
# d:\Anaconda\lib\site-packages\pyglet\image\codecs\wic.py:289: UserWarning: [WinError -2147417850] İş parçacığı modu kurulduktan sonra değiştirilemez
#   warnings.warn(str(err))
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20556\2993725579.py in <module>
#       5
#       6     action, _ = model.predict(state)
# ----> 7     state, reward, done, info = env.step(action)
#       8     env.render()
#
# d:\Anaconda\lib\site-packages\stable_baselines3\common\vec_env\base_vec_env.py in step(self, actions)
#     161         """
#     162         self.step_async(actions)
# --> 163         return self.step_wait()
#     164
#     165     def get_images(self) -> Sequence[np.ndarray]:
#
# d:\Anaconda\lib\site-packages\stable_baselines3\common\vec_env\vec_frame_stack.py in step_wait(self)
#      46     ) -> Tuple[Union[np.ndarray, Dict[str, np.ndarray]], np.ndarray, np.ndarray, List[Dict[str, Any]],]:
#      47
# ---> 48         observations, rewards, dones, infos = self.venv.step_wait()
#      49
#      50         observations, infos = self.stackedobs.update(observations, dones, infos)
#
# d:\Anaconda\lib\site-packages\stable_baselines3\common\vec_env\dummy_vec_env.py in step_wait(self)
#      52     def step_wait(self) -> VecEnvStepReturn:
#      53         for env_idx in range(self.num_envs):
# ---> 54             obs, self.buf_rews[env_idx], self.buf_dones[env_idx], self.buf_infos[env_idx] = self.envs[env_idx].step(
#      55                 self.actions[env_idx]
#      56             )
#
# d:\Anaconda\lib\site-packages\gym\core.py in step(self, action)
#     322     def step(self, action):
#     323         observation, reward, done, info = self.env.step(action)
# --> 324         return self.observation(observation), reward, done, info
#     325
#     326     @abstractmethod
#
# d:\Anaconda\lib\site-packages\gym\wrappers\gray_scale_observation.py in observation(self, observation)
#      29         import cv2
#      30
# ---> 31         observation = cv2.cvtColor(observation, cv2.COLOR_RGB2GRAY)
#      32         if self.keep_dim:
#      33             observation = np.expand_dims(observation, -1)
#
# KeyboardInterrupt:
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# model = DQN('CnnPolicy', env, verbose=1 ,tensorboard_log=LOG_DIR, learning_rate=0.0001)

# %%
# for i in range(10000):
#     model.learn(total_timesteps=stepsize ,reset_num_timesteps=False, tb_log_name='DQN-1')
#     model.save(f"{CHECKPOINT_DIR}\{stepsize*i}")
